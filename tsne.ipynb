# %% [markdown]
# <a href="https://colab.research.google.com/github/cellrishi-code/Unsupervised-learning/blob/main/tsne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.manifold import TSNE

# Load dataset
digits = load_digits()

X = digits.data       # 1797 samples, 64 features
y = digits.target     # actual digit labels (0 to 9)

print("Original shape:", X.shape)

# Create t-SNE model
tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate="auto",
    max_iter=1000,
    random_state=42
)

# Convert 64D -> 2D
X_tsne = tsne.fit_transform(X)

print("t-SNE shape:", X_tsne.shape)

# Plot
plt.figure(figsize=(10, 7))

scatter = plt.scatter(
    X_tsne[:, 0],
    X_tsne[:, 1],
    c=y,
    cmap="tab10",
    s=15
)

plt.colorbar(scatter, label="Digit")
plt.xlabel("t-SNE dimension 1")
plt.ylabel("t-SNE dimension 2")
plt.title("t-SNE Visualization of Digits Dataset")

plt.show()
# Out:
# Original shape: (1797, 64)
# t-SNE shape: (1797, 2)

# %%
## main application of T-sne
## 1.data visuiliaztin
## 2. seeing the cluster
## 3. perfroming the EDA
## 4. Visualizing neural-network embeddings
## 5. other usses in different domains i.e bioinfomtics , sales and many more
